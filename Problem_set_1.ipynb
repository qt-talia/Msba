# %% [markdown]
# Read the problem context carefully and develop your code. Your code should be well commented
# and remove any unnecessary code snippets.
# SD Retailing Inc. periodically monitors its warehouse management to generate key insights for
# its business. Warehouse management tools usually store and update information about available
# products in the form of inventory. SD Retailing Inc. tracks inventory in the following product
# categories: Hand soap, Moisturizer, Sunscreen, Body oil, and Shampoo. For each product in
# these categories, it monitors unit price (the price of each item), available quantity, expiration date
# of those products, and advance orders. Advance orders are orders customers place in advance.
# Expiration date tracks the “good days” left: 0 means it has expired. Once it has expired, the
# system removes the item, and employees also manually remove it from the warehouse so they do
# not have the item in physical form or in the digital system

# %%
#code straight from doc

#Importing the random library for generating random numbers
import random
random.seed(42) #You usually assign a seed to ensure replicability of random numbers
#Generate random inventory data for 5 product categories
def generate_inventory(num_categories=5, num_products_per_category=10):
categories = [‘Hand soap’, ‘Moisturizer’, ‘Sunscreen’, ‘Body oil’, and Shampoo’]
inventory = {}
for category in categories:
inventory[category] = []
for _ in range(num_products_per_category):
product = {
'Quantity': random.randint(10, 100),
'Unit Price': round(random.uniform(5.0, 500.0), 2)
'Expiration Date': random.randint(-2, 365),
'Advanced Ordered': random.randint(0, 8)
}
inventory[category].append(product)
return inventories
# Out:
#   Cell In[1], line 6
#     categories = [‘Hand soap’, ‘Moisturizer’, ‘Sunscreen’, ‘Body oil’, and Shampoo’]
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %% [markdown]
# 1. correcting all problem in the code (that I can notice)

# %%
#making my changes 
#Importing the random library for generating random numbers
import random
random.seed(42) #You usually assign a seed to ensure replicability of random numbers
#Generate random inventory data for 5 product categories
def generate_inventory(num_categories = 5, num_products_per_category = 10): #fixed the spacing
    categories = ['Hand soap', 'Moisturizer', 'Sunscreen', 'Body oil', 'Shampoo']  #fixed the quotes, removed and
    inventory = {}
    
    for category in categories: 
        inventory[category] = []
    
        for _ in range(num_products_per_category): #fixed indentation
            product = {
                'Quantity': random.randint(10, 100),
                'Unit Price': round(random.uniform(5.0, 500.0), 2), 
                'Expiration Date': random.randint(-2, 365),
                'Advanced Ordered': random.randint(0, 8)
        }
    inventory[category].append(product)

    return inventory 
    #overall fixed more spacing

# %% [markdown]
# 2. run the correct function to generate the inventory aka adding a new line

# %%
#making my changes 
#Importing the random library for generating random numbers
import random
random.seed(42) #You usually assign a seed to ensure replicability of random numbers
#Generate random inventory data for 5 product categories
def generate_inventory(num_categories = 5, num_products_per_category = 10): #fixed the spacing
    categories = ['Hand soap', 'Moisturizer', 'Sunscreen', 'Body oil', 'Shampoo']  #fixed the quotes, removed and
    inventory = {}
    
    for category in categories: 
        inventory[category] = []
    
        for _ in range(num_products_per_category): #fixed indentation
            product = {
                'Quantity': random.randint(10, 100),
                'Unit Price': round(random.uniform(5.0, 500.0), 2), 
                'Expiration Date': random.randint(-2, 365),
                'Advanced Ordered': random.randint(0, 8)
        }
    inventory[category].append(product)

    return inventory 
    #overall fixed more spacing

    #new line to generate
inventory = generate_inventory()
